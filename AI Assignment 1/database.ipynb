# %%
import pickle

# %%
# Modified destination dictionary for Religious Destinations
religious_destinations = {
    ('Religious', 'national', 'Hindu', 'Car/bus'): [
        {
            'destination': 'Somnath Temple, Gujarat',
            'budget_range': (50000, 100000),
            'preferences': {
                'accommodation_type': 'Heritage hotels in Gujarat',
                'food_preference': 'Traditional Gujarati cuisine'
            }
        },
        {
            'destination': 'Kedarnath, Uttarakhand',
            'budget_range': (60000, 120000),
            'preferences': {
                'accommodation_type': 'Mountain lodges in Uttarakhand',
                'food_preference': 'Local Uttarakhandi cuisine'
            }
        },
        {
            'destination': 'Vishvanath Temple, Varanasi',
            'budget_range': (55000, 110000),
            'preferences': {
                'accommodation_type': 'Varanasi guesthouses',
                'food_preference': 'Traditional Varanasi cuisine'
            }
        }
    ],
    ('Religious', 'national', 'Hindu', 'Railways'): [
        {
            'destination': 'Somnath Temple, Gujarat',
            'budget_range': (50000, 100000),
            'preferences': {
                'accommodation_type': 'Heritage hotels in Gujarat',
                'food_preference': 'Traditional Gujarati cuisine'
            }
        },
        {
            'destination': 'Kedarnath, Uttarakhand',
            'budget_range': (60000, 120000),
            'preferences': {
                'accommodation_type': 'Mountain lodges in Uttarakhand',
                'food_preference': 'Local Uttarakhandi cuisine'
            }
        },
        {
            'destination': 'Vishvanath Temple, Varanasi',
            'budget_range': (55000, 110000),
            'preferences': {
                'accommodation_type': 'Varanasi guesthouses',
                'food_preference': 'Traditional Varanasi cuisine'
            }
        }
    ],
    ('Religious', 'national', 'Hindu', 'Flight'): [
        {
            'destination': 'Somnath Temple, Gujarat',
            'budget_range': (60000, 120000),
            'preferences': {
                'accommodation_type': 'Heritage hotels in Gujarat',
                'food_preference': 'Traditional Gujarati cuisine'
            }
        },
        {
            'destination': 'Kedarnath, Uttarakhand',
            'budget_range': (70000, 140000),
            'preferences': {
                'accommodation_type': 'Mountain lodges in Uttarakhand',
                'food_preference': 'Local Uttarakhandi cuisine'
            }
        },
        {
            'destination': 'Vishvanath Temple, Varanasi',
            'budget_range': (65000, 130000),
            'preferences': {
                'accommodation_type': 'Varanasi guesthouses',
                'food_preference': 'Traditional Varanasi cuisine'
            }
        }
    ],
    ('Religious', 'national', 'Islamic','Car/bus'): [
        {
            'destination': 'Hazratbal Shrine Srinagar',
            'budget_range': (45000, 90000),
            'preferences': {
                'accommodation_type': 'Local hotels in Srinagar',
                'food_preference': 'Kashmiri cuisine'
            }
        },
        {
            'destination': 'Haji Ali Dargah, Mumbai',
            'budget_range': (40000, 80000),
            'preferences': {
                'accommodation_type': 'Hotels in Mumbai',
                'food_preference': 'Mumbai street food'
            }
        },
        {
            'destination': 'Ajmer Sharif, Ajmer, Rajasthan',
            'budget_range': (35000, 70000),
            'preferences': {
                'accommodation_type': 'Hotels in Ajmer',
                'food_preference': 'Rajasthani cuisine'
            }
        }
    ],
    ('Religious', 'national', 'Islamic','Railways' ): [
        {
            'destination': 'Hazratbal Shrine Srinagar',
            'budget_range': (45000, 90000),
            'preferences': {
                'accommodation_type': 'Local hotels in Srinagar',
                'food_preference': 'Kashmiri cuisine'
            }
        },
        {
            'destination': 'Haji Ali Dargah, Mumbai',
            'budget_range': (40000, 80000),
            'preferences': {
                'accommodation_type': 'Hotels in Mumbai',
                'food_preference': 'Mumbai street food'
            }
        },
        {
            'destination': 'Ajmer Sharif, Ajmer, Rajasthan',
            'budget_range': (35000, 70000),
            'preferences': {
                'accommodation_type': 'Hotels in Ajmer',
                'food_preference': 'Rajasthani cuisine'
            }
        }
    ],
    ('Religious', 'national', 'Islamic','Flight' ): [
        {
            'destination': 'Hazratbal Shrine Srinagar',
            'budget_range': (50000, 100000),
            'preferences': {
                'accommodation_type': 'Luxury hotels in Srinagar',
                'food_preference': 'Fine Kashmiri dining'
            }
        },
        {
            'destination': 'Haji Ali Dargah, Mumbai',
            'budget_range': (55000, 110000),
            'preferences': {
                'accommodation_type': 'Luxury hotels in Mumbai',
                'food_preference': 'Gourmet Indian cuisine'
            }
        },
        {
            'destination': 'Ajmer Sharif, Ajmer, Rajasthan',
            'budget_range': (52000, 104000),
            'preferences': {
                'accommodation_type': 'Luxury hotels in Ajmer',
                'food_preference': 'Exquisite Rajasthani dishes'
            }
        }
    ],
    ('Religious', 'national', 'Sikh', 'Car/bus'): [
        {
            'destination': 'Golden Temple, Amritsar',
            'budget_range': (45000, 90000),
            'preferences': {
                'accommodation_type': 'Hotels in Amritsar',
                'food_preference': 'Punjabi cuisine'
            }
        },
        {
            'destination': 'Hemkund Sahib, Himachal Pradesh',
            'budget_range': (50000, 100000),
            'preferences': {
                'accommodation_type': 'Lodges in Himachal Pradesh',
                'food_preference': 'Himachali cuisine'
            }
        }
    ],
    ('Religious', 'national', 'Sikh', 'Railways' ): [
        {
            'destination': 'Golden Temple, Amritsar',
            'budget_range': (45000, 90000),
            'preferences': {
                'accommodation_type': 'Hotels in Amritsar',
                'food_preference': 'Punjabi cuisine'
            }
        },
        {
            'destination': 'Hemkund Sahib, Himachal Pradesh',
            'budget_range': (50000, 100000),
            'preferences': {
                'accommodation_type': 'Lodges in Himachal Pradesh',
                'food_preference': 'Himachali cuisine'
            }
        }
    ],
    ('Religious', 'national', 'Sikh', 'Flight'): [
        {
            'destination': 'Golden Temple, Amritsar',
            'budget_range': (50000, 100000),
            'preferences': {
                'accommodation_type': 'Luxury hotels in Amritsar',
                'food_preference': 'Fine Punjabi dining'
            }
        },
        {
            'destination': 'Hemkund Sahib, Himachal Pradesh',
            'budget_range': (55000, 110000),
            'preferences': {
                'accommodation_type': 'Luxury lodges in Himachal Pradesh',
                'food_preference': 'Gourmet Himachali cuisine'
            }
        }
    ],
    ('Religious', 'national', 'Jainism', 'Car/bus'): [
        {
            'destination': 'Dilwara Temple, Mount Abu',
            'budget_range': (45000, 90000),
            'preferences': {
                'accommodation_type': 'Hotels in Mount Abu',
                'food_preference': 'Rajasthani and Jain cuisine'
            }
        },
        {
            'destination': 'Ranakpur Jain Temple, Ranakpur',
            'budget_range': (48000, 96000),
            'preferences': {
                'accommodation_type': 'Hotels near Ranakpur Temple',
                'food_preference': 'Local Rajasthani dishes'
            }
        },
        {
            'destination': 'Palitana Temples, Bhavnagar District (Gujarat)',
            'budget_range': (50000, 100000),
            'preferences': {
                'accommodation_type': 'Hotels in Bhavnagar',
                'food_preference': 'Gujarati cuisine'
            }
        }
    ],
    ('Religious', 'national', 'Jainism', 'Railways'): [
        {
            'destination': 'Dilwara Temple, Mount Abu',
            'budget_range': (45000, 90000),
            'preferences': {
                'accommodation_type': 'Hotels in Mount Abu',
                'food_preference': 'Rajasthani and Jain cuisine'
            }
        },
        {
            'destination': 'Ranakpur Jain Temple, Ranakpur',
            'budget_range': (48000, 96000),
            'preferences': {
                'accommodation_type': 'Hotels near Ranakpur Temple',
                'food_preference': 'Local Rajasthani dishes'
            }
        },
        {
            'destination': 'Palitana Temples, Bhavnagar District (Gujarat)',
            'budget_range': (50000, 100000),
            'preferences': {
                'accommodation_type': 'Hotels in Bhavnagar',
                'food_preference': 'Gujarati cuisine'
            }
        }
    ],
    ('Religious', 'international', 'Buddhist', 'Flight'): [
        {
            'destination': 'Lumbini, Nepal',
            'budget_range': (55000, 110000),
            'preferences': {
                'accommodation_type': 'Buddhist monasteries in Lumbini',
                'food_preference': 'Nepali and Tibetan cuisine'
            }
        }
    ],
    ('Religious', 'international', 'Christian', 'Flight'): [
        {
            'destination': 'Vatican City',
            'budget_range': (70000, 140000),
            'preferences': {
                'accommodation_type': 'Hotels in Vatican City',
                'food_preference': 'Italian cuisine'
            }
        },
        {
            'destination': 'Jerusalem',
            'budget_range': (65000, 130000),
            'preferences': {
                'accommodation_type': 'Hotels in Jerusalem',
                'food_preference': 'Middle Eastern cuisine'
            }
        },
        {
            'destination': 'Lourdes, France',
            'budget_range': (60000, 120000),
            'preferences': {
                'accommodation_type': 'Hotels in Lourdes',
                'food_preference': 'French cuisine'
            }
        }
    ],
    ('Religious', 'international', 'Christian', 'Ship'): [
        {
            'destination': 'Vatican City',
            'budget_range': (90000, 180000),
            'preferences': {
                'accommodation_type': 'Cruise ship accommodations',
                'food_preference': 'International cuisine on the ship'
            }
        },
        {
            'destination': 'Jerusalem',
            'budget_range': (85000, 170000),
            'preferences': {
                'accommodation_type': 'Cruise ship accommodations',
                'food_preference': 'International cuisine on the ship'
            }
        },
        {
            'destination': 'Lourdes, France',
            'budget_range': (80000, 160000),
            'preferences': {
                'accommodation_type': 'Cruise ship accommodations',
                'food_preference': 'International cuisine on the ship'
            }
        }
    ]
}

# %%
print(religious_destinations[('Religious', 'international', 'Christian', 'Ship')])
# Out:
# [{'destination': 'Vatican City', 'budget_range': (90000, 180000), 'preferences': {'accommodation_type': 'Cruise ship accommodations', 'food_preference': 'International cuisine on the ship'}}, {'destination': 'Jerusalem', 'budget_range': (85000, 170000), 'preferences': {'accommodation_type': 'Cruise ship accommodations', 'food_preference': 'International cuisine on the ship'}}, {'destination': 'Lourdes, France', 'budget_range': (80000, 160000), 'preferences': {'accommodation_type': 'Cruise ship accommodations', 'food_preference': 'International cuisine on the ship'}}]

# %%
camping_destinations = {
    ('Camping', 'international', 'Tent Camping', 'Flight'): [
        {
            'destination': 'Dry Tortugas National Park, Florida',
            'budget_range': (75000, 150000),
            'preferences': {
                'accommodation_type': 'Tent',
                'food_preference': 'Campfire Cooking'
            }
        },
        {
            'destination': 'Minnewaska State Park Reserve, New York',
            'budget_range': (80000, 160000),
            'preferences': {
                'accommodation_type': 'Tent',
                'food_preference': 'Outdoor Grill'
            }
        }
    ],
    ('Camping', 'national', 'Tent Camping', 'Car/Bus'): [
        {
            'destination': 'Camp Mustang, Sohna Road',
            'budget_range': (2000, 4000),
            'preferences': {
                'accommodation_type': 'Tent',
                'food_preference': 'Campfire Cooking'
            }
        },
        {
            'destination': 'Damdama Lake, Gurgaon',
            'budget_range': (2500, 5000),
            'preferences': {
                'accommodation_type': 'Tent',
                'food_preference': 'Picnic-style'
            }
        },
        {
            'destination': 'Camp Tikkling, Gurgaon',
            'budget_range': (2200, 4400),
            'preferences': {
                'accommodation_type': 'Tent',
                'food_preference': 'Barbecue'
            }
        }
    ],
    ('Camping', 'national', 'Glamping', 'Car/Bus'): [
        {
            'destination': 'Sherbagh, Ranthambore',
            'budget_range': (15000, 30000),
            'preferences': {
                'accommodation_type': 'Luxury Tent',
                'food_preference': 'Fine Dining'
            }
        },
        {
            'destination': 'Tree House Resort, Jaipur',
            'budget_range': (18000, 36000),
            'preferences': {
                'accommodation_type': 'Tree House',
                'food_preference': 'Local Cuisine'
            }
        },
        {
            'destination': 'Serai, Jaisalmer',
            'budget_range': (20000, 40000),
            'preferences': {
                'accommodation_type': 'Luxury Tent',
                'food_preference': 'Gourmet'
            }
        }
    ],
    ('Camping', 'national', 'Glamping', 'Railways'): [
        {
            'destination': 'Sherbagh, Ranthambore',
            'budget_range': (15000, 30000),
            'preferences': {
                'accommodation_type': 'Luxury Tent',
                'food_preference': 'Fine Dining'
            }
        },
        {
            'destination': 'Tree House Resort, Jaipur',
            'budget_range': (18000, 36000),
            'preferences': {
                'accommodation_type': 'Tree House',
                'food_preference': 'Local Cuisine'
            }
        },
        {
            'destination': 'Serai, Jaisalmer',
            'budget_range': (20000, 40000),
            'preferences': {
                'accommodation_type': 'Luxury Tent',
                'food_preference': 'Gourmet'
            }
        }
    ],
    ('Camping', 'international', 'Glamping', 'Flight'): [
        {
            'destination': 'Huttopia White Mountains, Conway',
            'budget_range': (120000, 240000),
            'preferences': {
                'accommodation_type': 'Luxury Tent',
                'food_preference': 'Gourmet'
            }
        },
        {
            'destination': 'Dunton River Camp, Dolores',
            'budget_range': (140000, 280000),
            'preferences': {
                'accommodation_type': 'Luxury Tent',
                'food_preference': 'Fine Dining'
            }
        },
        {
            'destination': 'Firelight Camps, Ithaca',
            'budget_range': (100000, 200000),
            'preferences': {
                'accommodation_type': 'Safari Tent',
                'food_preference': 'Local Cuisine'
            }
        }
    ],
    ('Camping', 'international', 'Backpacking', 'Flight'): [
        {
            'destination': 'Unawatuna, Sri Lanka',
            'budget_range': (60000, 120000),
            'preferences': {
                'accommodation_type': 'Backpacker Hostel',
                'food_preference': 'Local Street Food'
            }
        },
        {
            'destination': 'Queenstown, New Zealand',
            'budget_range': (80000, 160000),
            'preferences': {
                'accommodation_type': 'Backpacker Hostel',
                'food_preference': 'Outdoor Grill'
            }
        },
        {
            'destination': 'Palawan, the Philippines',
            'budget_range': (70000, 140000),
            'preferences': {
                'accommodation_type': 'Camping Site',
                'food_preference': 'Campfire Cooking'
            }
        }
    ],
    ('Camping', 'international', 'Backpacking', 'Ship'): [
        {
            'destination': 'Unawatuna, Sri Lanka',
            'budget_range': (70000, 140000),
            'preferences': {
                'accommodation_type': 'Backpacker Hostel',
                'food_preference': 'Local Street Food'
            }
        },
        {
            'destination': 'Queenstown, New Zealand',
            'budget_range': (90000, 180000),
            'preferences': {
                'accommodation_type': 'Backpacker Hostel',
                'food_preference': 'Outdoor Grill'
            }
        },
        {
            'destination': 'Palawan, the Philippines',
            'budget_range': (80000, 160000),
            'preferences': {
                'accommodation_type': 'Camping Site',
                'food_preference': 'Campfire Cooking'
            }
        }
    ],
    ('Camping', 'international', 'RV Camping', 'Flight'): [
        {
            'destination': 'Yellowstone National Park, USA',
            'budget_range': (90000, 180000),
            'preferences': {
                'accommodation_type': 'RV Campground',
                'food_preference': 'Outdoor Grill'
            }
        },
        {
            'destination': 'Banff National Park, Canada',
            'budget_range': (100000, 200000),
            'preferences': {
                'accommodation_type': 'RV Campground',
                'food_preference': 'Campfire Cooking'
            }
        },
        {
            'destination': 'Great Ocean Road, Australia',
            'budget_range': (80000, 160000),
            'preferences': {
                'accommodation_type': 'RV Campground',
                'food_preference': 'Outdoor Grill'
            }
        }
    ]
}

# %%
mountain_destinations = {
    ('Mountains', 'national', 'North', 'Car/Bus'): [
        {
            'destination': 'Leh, Lahaul Spiti',
            'budget_range': (10000, 20000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Local Cuisine'
            }
        },
        {
            'destination': 'Shimla',
            'budget_range': (8000, 16000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Himachali Dishes'
            }
        },
        {
            'destination': 'Dharamshala',
            'budget_range': (9000, 18000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Tibetan Cuisine'
            }
        },
        {
            'destination': 'Dalhousie',
            'budget_range': (9500, 19000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Local Himachali Food'
            }
        },
        {
            'destination': 'Mussorie',
            'budget_range': (8500, 17000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'North Indian Cuisine'
            }
        },
        {
            'destination': 'Chamba',
            'budget_range': (10000, 20000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Local Himachali Food'
            }
        }
    ],
    ('Mountains', 'national', 'North', 'Railways'): [
        {
            'destination': 'Leh, Lahaul Spiti',
            'budget_range': (11000, 22000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Local Cuisine'
            }
        },
        {
            'destination': 'Shimla',
            'budget_range': (9000, 18000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Himachali Dishes'
            }
        },
        {
            'destination': 'Dharamshala',
            'budget_range': (10000, 20000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Tibetan Cuisine'
            }
        },
        {
            'destination': 'Dalhousie',
            'budget_range': (10500, 21000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Local Himachali Food'
            }
        },
        {
            'destination': 'Mussorie',
            'budget_range': (9500, 19000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'North Indian Cuisine'
            }
        },
        {
            'destination': 'Chamba',
            'budget_range': (11000, 22000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Local Himachali Food'
            }
        }
    ],
    ('Mountains', 'national', 'North', 'Flight'): [
        {
            'destination': 'Leh, Lahaul Spiti',
            'budget_range': (20000, 40000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Local Cuisine'
            }
        },
        {
            'destination': 'Chamba',
            'budget_range': (18000, 36000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Local Himachali Food'
            }
        }
    ],
    ('Mountains', 'national', 'East', 'Flight'): [
        {
            'destination': 'Shillong',
            'budget_range': (12000, 24000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Khasi Delicacies'
            }
        },
        {
            'destination': 'Pelling',
            'budget_range': (13000, 26000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Sikkimese Cuisine'
            }
        },
        {
            'destination': 'Darjeeling',
            'budget_range': (14000, 28000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Darjeeling Tea and Momos'
            }
        },
        {
            'destination': 'Tawang',
            'budget_range': (16000, 32000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Arunachali Dishes'
            }
        }
    ],
    ('Mountains', 'national', 'East', 'Car/Bus'): [
        {
            'destination': 'Shillong',
            'budget_range': (8000, 16000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Khasi Delicacies'
            }
        },
        {
            'destination': 'Pelling',
            'budget_range': (9000, 18000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Sikkimese Cuisine'
            }
        },
        {
            'destination': 'Darjeeling',
            'budget_range': (9500, 19000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Darjeeling Tea and Momos'
            }
        },
        {
            'destination': 'Tawang',
            'budget_range': (11000, 22000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Arunachali Dishes'
            }
        }
    ],
    ('Mountains', 'national', 'East', 'Railways'): [
        {
            'destination': 'Shillong',
            'budget_range': (9000, 18000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Khasi Delicacies'
            }
        },
        {
            'destination': 'Pelling',
            'budget_range': (10000, 20000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Sikkimese Cuisine'
            }
        },
        {
            'destination': 'Darjeeling',
            'budget_range': (10500, 21000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Darjeeling Tea and Momos'
            }
        },
        {
            'destination': 'Tawang',
            'budget_range': (12000, 24000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Arunachali Dishes'
            }
        }
    ],
    ('Mountains', 'national', 'South', 'Railways'): [
        {
            'destination': 'Yercaud, Tamil Nadu',
            'budget_range': (6000, 12000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'South Indian Cuisine'
            }
        },
        {
            'destination': 'Yelagiri, Tamil Nadu',
            'budget_range': (6500, 13000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'South Indian Delights'
            }
        },
        {
            'destination': 'Coonoor, Tamil Nadu',
            'budget_range': (7000, 14000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Nilgiri Cuisine'
            }
        },
        {
            'destination': 'Kotagiri, Tamil Nadu',
            'budget_range': (7500, 15000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Hill Station Eats'
            }
        }
    ],
    ('Mountains', 'national', 'South', 'Flight'): [
        {
            'destination': 'Yercaud, Tamil Nadu',
            'budget_range': (12000, 24000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'South Indian Cuisine'
            }
        },
        {
            'destination': 'Yelagiri, Tamil Nadu',
            'budget_range': (13000, 26000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'South Indian Delights'
            }
        },
        {
            'destination': 'Coonoor, Tamil Nadu',
            'budget_range': (14000, 28000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Nilgiri Cuisine'
            }
        },
        {
            'destination': 'Kotagiri, Tamil Nadu',
            'budget_range': (15000, 30000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Hill Station Eats'
            }
        }
    ],
    ('Mountains', 'national', 'West', 'Railways'): [
        {
            'destination': 'Mahabaleshwar',
            'budget_range': (8000, 16000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Strawberries and Cream'
            }
        },
        {
            'destination': 'Khandala',
            'budget_range': (8500, 17000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Pav Bhaji and Chikki'
            }
        },
        {
            'destination': 'Mount Abu',
            'budget_range': (9000, 18000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Rajasthani Thali'
            }
        },
        {
            'destination': 'Saputara',
            'budget_range': (7500, 15000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Gujarati Cuisine'
            }
        },
        {
            'destination': 'Kamshet',
            'budget_range': (7500, 15000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Maharashtrian Delicacies'
            }
        },
        {
            'destination': 'Lavasa',
            'budget_range': (8000, 16000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'International Cuisine'
            }
        }
    ],
    ('Mountains', 'national', 'West', 'Car/Bus'): [
        {
            'destination': 'Mahabaleshwar',
            'budget_range': (6000, 12000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Strawberries and Cream'
            }
        },
        {
            'destination': 'Khandala',
            'budget_range': (6500, 13000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Pav Bhaji and Chikki'
            }
        },
        {
            'destination': 'Mount Abu',
            'budget_range': (7000, 14000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Rajasthani Thali'
            }
        },
        {
            'destination': 'Saputara',
            'budget_range': (5500, 11000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Gujarati Cuisine'
            }
        },
        {
            'destination': 'Kamshet',
            'budget_range': (5500, 11000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Maharashtrian Delicacies'
            }
        },
        {
            'destination': 'Lavasa',
            'budget_range': (6000, 12000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'International Cuisine'
            }
        }
    ],
    ('Mountains', 'national', 'Himalayas', 'Railways'): [
        {
            'destination': 'Nepal Himalayas',
            'budget_range': (18000, 36000),
            'preferences': {
                'accommodation_type': 'Tea House',
                'food_preference': 'Nepali Cuisine'
            }
        },
        {
            'destination': 'Bhutan Himalayas',
            'budget_range': (20000, 40000),
            'preferences': {
                'accommodation_type': 'Guest House',
                'food_preference': 'Bhutanese Food'
            }
        },
        {
            'destination': 'Karakoram Range India',
            'budget_range': (22000, 44000),
            'preferences': {
                'accommodation_type': 'Trekking Camp',
                'food_preference': 'Trekking Meals'
            }
        },
        {
            'destination': 'Sikkim Himalayas',
            'budget_range': (19000, 38000),
            'preferences': {
                'accommodation_type': 'Hotel',
                'food_preference': 'Sikkimese Delights'
            }
        }
    ],
    ('Mountains', 'international', 'Flight'): [
        {
            'destination': 'Machu Picchu, Peru',
            'budget_range': (250000, 500000),
            'preferences': {
                'accommodation_type': 'Lodge',
                'food_preference': 'Peruvian Cuisine'
            }
        },
        {
            'destination': 'Swiss Alps, Switzerland',
            'budget_range': (180000, 360000),
            'preferences': {
                'accommodation_type': 'Alpine Chalet',
                'food_preference': 'Swiss Fondue'
            }
        },
        {
            'destination': 'Patagonia, Argentina',
            'budget_range': (220000, 440000),
            'preferences': {
                'accommodation_type': 'Eco Lodge',
                'food_preference': 'Argentinian Steak'
            }
        }
    ]
}

# %%
sanctuary_destinations = {
    ('Sanctuaries', 'national', 'Marine', 'Car/Bus'): [
        {
            'destination': 'Malvan Marine Sanctuary',
            'budget_range': (8000, 16000),
            'preferences': {
                'accommodation_type': 'Beachfront Cottage',
                'food_preference': 'Fresh Seafood'
            }
        },
        {
            'destination': 'Sindhudurg, Maharashtra',
            'budget_range': (8500, 17000),
            'preferences': {
                'accommodation_type': 'Coastal Homestay',
                'food_preference': 'Konkani Cuisine'
            }
        },
        {
            'destination': 'Gahirmatha Marine Sanctuary, Odisha',
            'budget_range': (9000, 18000),
            'preferences': {
                'accommodation_type': 'Houseboat',
                'food_preference': 'Odia Delicacies'
            }
        },
        {
            'destination': 'Gulf of Mannar Marine National Park',
            'budget_range': (9500, 19000),
            'preferences': {
                'accommodation_type': 'Floating Bungalow',
                'food_preference': 'Tamil Coastal Food'
            }
        }
    ],
    ('Sanctuaries', 'national', 'Marine', 'Railways'): [
        {
            'destination': 'Malvan Marine Sanctuary',
            'budget_range': (8000, 16000),
            'preferences': {
                'accommodation_type': 'Beachfront Cottage',
                'food_preference': 'Fresh Seafood'
            }
        },
        {
            'destination': 'Sindhudurg, Maharashtra',
            'budget_range': (8500, 17000),
            'preferences': {
                'accommodation_type': 'Coastal Homestay',
                'food_preference': 'Konkani Cuisine'
            }
        },
        {
            'destination': 'Gahirmatha Marine Sanctuary, Odisha',
            'budget_range': (9000, 18000),
            'preferences': {
                'accommodation_type': 'Houseboat',
                'food_preference': 'Odia Delicacies'
            }
        },
        {
            'destination': 'Gulf of Mannar Marine National Park',
            'budget_range': (9500, 19000),
            'preferences': {
                'accommodation_type': 'Floating Bungalow',
                'food_preference': 'Tamil Coastal Food'
            }
        }
    ],
    ('Sanctuaries', 'international', 'Marine', 'Flight'): [
        {
            'destination': 'Channel Islands National Marine Sanctuary',
            'budget_range': (18000, 36000),
            'preferences': {
                'accommodation_type': 'Island Resort',
                'food_preference': 'Seafood Extravaganza'
            }
        },
        {
            'destination': 'Cordell Bank National Marine Sanctuary',
            'budget_range': (20000, 40000),
            'preferences': {
                'accommodation_type': 'Underwater Hotel',
                'food_preference': 'Oceanic Gourmet'
            }
        }
    ],
    ('Sanctuaries', 'national', 'Areial', 'Car/Bus'): [
        {
            'destination': 'Najafgarh Drain Bird Sanctuary, Delhi',
            'budget_range': (6000, 12000),
            'preferences': {
                'accommodation_type': 'Riverside Camp',
                'food_preference': 'North Indian Cuisine'
            }
        },
        {
            'destination': 'Salim Ali Bird Sanctuary, Goa',
            'budget_range': (6500, 13000),
            'preferences': {
                'accommodation_type': 'Treehouse Retreat',
                'food_preference': 'Goan Delights'
            }
        },
        {
            'destination': 'Gaga Wildlife Sanctuary, Gujarat',
            'budget_range': (7000, 14000),
            'preferences': {
                'accommodation_type': 'Wilderness Lodge',
                'food_preference': 'Gujarati Flavors'
            }
        },
        {
            'destination': 'Khijadiya Bird Sanctuary, Gujarat',
            'budget_range': (7500, 15000),
            'preferences': {
                'accommodation_type': 'Marshside Cabin',
                'food_preference': 'Local Birdwatcher\'s Platter'
            }
        }
    ],
    ('Sanctuaries', 'national', 'Areial', 'Railways'): [
        {
            'destination': 'Najafgarh Drain Bird Sanctuary, Delhi',
            'budget_range': (6000, 12000),
            'preferences': {
                'accommodation_type': 'Riverside Camp',
                'food_preference': 'North Indian Cuisine'
            }
        },
        {
            'destination': 'Salim Ali Bird Sanctuary, Goa',
            'budget_range': (6500, 13000),
            'preferences': {
                'accommodation_type': 'Treehouse Retreat',
                'food_preference': 'Goan Delights'
            }
        },
        {
            'destination': 'Gaga Wildlife Sanctuary, Gujarat',
            'budget_range': (7000, 14000),
            'preferences': {
                'accommodation_type': 'Wilderness Lodge',
                'food_preference': 'Gujarati Flavors'
            }
        },
        {
            'destination': 'Khijadiya Bird Sanctuary, Gujarat',
            'budget_range': (7500, 15000),
            'preferences': {
                'accommodation_type': 'Marshside Cabin',
                'food_preference': 'Local Birdwatcher\'s Platter',
            }
        }
    ],
    ('Sanctuaries', 'national', 'Areial', 'Flight'): [
        {
            'destination': 'Najafgarh Drain Bird Sanctuary, Delhi',
            'budget_range': (12000, 24000),
            'preferences': {
                'accommodation_type': 'Riverside Camp',
                'food_preference': 'North Indian Cuisine'
            }
        },
        {
            'destination': 'Salim Ali Bird Sanctuary, Goa',
            'budget_range': (13000, 26000),
            'preferences': {
                'accommodation_type': 'Treehouse Retreat',
                'food_preference': 'Goan Delights'
            }
        },
        {
            'destination': 'Gaga Wildlife Sanctuary, Gujarat',
            'budget_range': (14000, 28000),
            'preferences': {
                'accommodation_type': 'Wilderness Lodge',
                'food_preference': 'Gujarati Flavors'
            }
        },
        {
            'destination': 'Khijadiya Bird Sanctuary, Gujarat',
            'budget_range': (15000, 30000),
            'preferences': {
                'accommodation_type': 'Marshside Cabin',
                'food_preference': 'Local Birdwatcher\'s Platter',
            }
        }
    ],
    ('Sanctuaries', 'international', 'Areial', 'Flight'): [
        {
            'destination': 'Weltvogelpark Walsrode, Germany',
            'budget_range': (25000, 50000),
            'preferences': {
                'accommodation_type': 'Aviary Retreat',
                'food_preference': 'German Avian Delicacies'
            }
        },
        {
            'destination': 'Jurong Bird Park, Singapore',
            'budget_range': (28000, 56000),
            'preferences': {
                'accommodation_type': 'Canopy Resort',
                'food_preference': 'Singaporean Bird\'s Nest Soup'
            }
        }
    ],
    ('Sanctuaries', 'national', 'Terrestial', 'Car/Bus'): [
        {
            'destination': 'Jim Corbett National Park, Uttarakhand',
            'budget_range': (10000, 20000),
            'preferences': {
                'accommodation_type': 'Riverside Lodge',
                'food_preference': 'North Indian Cuisine'
            }
        },
        {
            'destination': 'Ranthambore National Park, Rajasthan',
            'budget_range': (11000, 22000),
            'preferences': {
                'accommodation_type': 'Safari Camp',
                'food_preference': 'Rajasthani Thali'
            }
        },
        {
            'destination': 'Gir National Park, Gujarat',
            'budget_range': (12000, 24000),
            'preferences': {
                'accommodation_type': 'Wildlife Resort',
                'food_preference': 'Gujarati Flavors'
            }
        },
        {
            'destination': 'Kaziranga National Park, Assam',
            'budget_range': (13000, 26000),
            'preferences': {
                'accommodation_type': 'Jungle Cottage',
                'food_preference': 'Assamese Delights'
            }
        }
    ],
    ('Sanctuaries', 'national', 'Terrestial', 'Railways'): [
        {
            'destination': 'Jim Corbett National Park, Uttarakhand',
            'budget_range': (10000, 20000),
            'preferences': {
                'accommodation_type': 'Riverside Lodge',
                'food_preference': 'North Indian Cuisine'
            }
        },
        {
            'destination': 'Ranthambore National Park, Rajasthan',
            'budget_range': (11000, 22000),
            'preferences': {
                'accommodation_type': 'Safari Camp',
                'food_preference': 'Rajasthani Thali'
            }
        },
        {
            'destination': 'Gir National Park, Gujarat',
            'budget_range': (12000, 24000),
            'preferences': {
                'accommodation_type': 'Wildlife Resort',
                'food_preference': 'Gujarati Flavors'
            }
        },
        {
            'destination': 'Kaziranga National Park, Assam',
            'budget_range': (13000, 26000),
            'preferences': {
                'accommodation_type': 'Jungle Cottage',
                'food_preference': 'Assamese Delights'
            }
        }
    ],
    ('Sanctuaries', 'national', 'Terrestial', 'Flight'): [
        {
            'destination': 'Jim Corbett National Park, Uttarakhand',
            'budget_range': (20000, 40000),
            'preferences': {
                'accommodation_type': 'Riverside Lodge',
                'food_preference': 'North Indian Cuisine'
            }
        },
        {
            'destination': 'Ranthambore National Park, Rajasthan',
            'budget_range': (22000, 44000),
            'preferences': {
                'accommodation_type': 'Safari Camp',
                'food_preference': 'Rajasthani Thali'
            }
        },
        {
            'destination': 'Gir National Park, Gujarat',
            'budget_range': (24000, 48000),
            'preferences': {
                'accommodation_type': 'Wildlife Resort',
                'food_preference': 'Gujarati Flavors'
            }
        },
        {
            'destination': 'Kaziranga National Park, Assam',
            'budget_range': (26000, 52000),
            'preferences': {
                'accommodation_type': 'Jungle Cottage',
                'food_preference': 'Assamese Delights'
            }
        }
    ],
    ('Sanctuaries', 'international', 'Terrestial', 'Flight'): [
        {
            'destination': 'Grand Canyon National Park, USA',
            'budget_range': (35000, 70000),
            'preferences': {
                'accommodation_type': 'Canyon Retreat',
                'food_preference': 'American BBQ'
            }
        },
        {
            'destination': 'Great Barrier Reef National Park, Australia',
            'budget_range': (38000, 76000),
            'preferences': {
                'accommodation_type': 'Reef Bungalow',
                'food_preference': 'Aussie Seafood'
            }
        },
        {
            'destination': 'Kruger National Park, South Africa',
            'budget_range': (40000, 80000),
            'preferences': {
                'accommodation_type': 'Safari Lodge',
                'food_preference': 'South African Braai'
            }
        }
    ],
    ('Sanctuaries', 'international', 'Rainforest', 'Flight'): [
        {
            'destination': 'Sinharaja Forest Reserve, Sri Lanka',
            'budget_range': (25000, 50000),
            'preferences': {
                'accommodation_type': 'Treehouse Retreat',
                'food_preference': 'Sri Lankan Spice'
            }
        },
        {
            'destination': 'Taman Negara National Park, Malaysia',
            'budget_range': (28000, 56000),
            'preferences': {
                'accommodation_type': 'Jungle Camp',
                'food_preference': 'Malaysian Fusion'
            }
        }
    ],
    ('Sanctuaries', 'international', 'Zoo', 'Flight'): [
        {
            'destination': 'Tiergarten Schönbrunn, Vienna, Austria',
            'budget_range': (20000, 40000),
            'preferences': {
                'accommodation_type': 'Zoo Lodge',
                'food_preference': 'Austrian Cuisine'
            }
        },
        {
            'destination': 'Bronx Zoo, New York City, USA',
            'budget_range': (22000, 44000),
            'preferences': {
                'accommodation_type': 'Wildlife Retreat',
                'food_preference': 'American Delights'
            }
        },
        {
            'destination': 'San Diego Zoo, San Diego, USA',
            'budget_range': (24000, 48000),
            'preferences': {
                'accommodation_type': 'Safari Cabin',
                'food_preference': 'Californian Fare'
            }
        },
        {
            'destination': 'Singapore Zoo, Singapore',
            'budget_range': (26000, 52000),
            'preferences': {
                'accommodation_type': 'Zoo Oasis',
                'food_preference': 'Singaporean Cuisine'
            }
        }
    ],
    ('Sanctuaries', 'national', 'Zoo', 'Car/Bus'): [
        {
            'destination': 'Nandankanan Zoological Park, Bhubaneshwar',
            'budget_range': (8000, 16000),
            'preferences': {
                'accommodation_type': 'Zoo View Resort',
                'food_preference': 'Odia Delicacies'
            }
        },
        {
            'destination': 'Indira Gandhi Zoological Park, Andhra Pradesh',
            'budget_range': (8500, 17000),
            'preferences': {
                'accommodation_type': 'Wildlife Cottage',
                'food_preference': 'Andhra Cuisine'
            }
        },
        {
            'destination': 'Allen Forest Zoo, Kanpur',
            'budget_range': (9000, 18000),
            'preferences': {
                'accommodation_type': 'Zooside Bungalow',
                'food_preference': 'North Indian Flavors'
            }
        }
    ],
    ('Sanctuaries', 'national', 'Zoo', 'Railways'): [
        {
            'destination': 'Nandankanan Zoological Park, Bhubaneshwar',
            'budget_range': (8000, 16000),
            'preferences': {
                'accommodation_type': 'Zoo View Resort',
                'food_preference': 'Odia Delicacies'
            }
        },
        {
            'destination': 'Indira Gandhi Zoological Park, Andhra Pradesh',
            'budget_range': (8500, 17000),
            'preferences': {
                'accommodation_type': 'Wildlife Cottage',
                'food_preference': 'Andhra Cuisine'
            }
        },
        {
            'destination': 'Allen Forest Zoo, Kanpur',
            'budget_range': (9000, 18000),
            'preferences': {
                'accommodation_type': 'Zooside Bungalow',
                'food_preference': 'North Indian Flavors'
            }
        }
    ],
    ('Sanctuaries', 'national', 'Zoo', 'Flight'): [
        {
            'destination': 'Nandankanan Zoological Park, Bhubaneshwar',
            'budget_range': (16000, 32000),
            'preferences': {
                'accommodation_type': 'Zoo View Resort',
                'food_preference': 'Odia Delicacies'
            }
        },
        {
            'destination': 'Indira Gandhi Zoological Park, Andhra Pradesh',
            'budget_range': (17000, 34000),
            'preferences': {
                'accommodation_type': 'Wildlife Cottage',
                'food_preference': 'Andhra Cuisine'
            }
        },
        {
            'destination': 'Allen Forest Zoo, Kanpur',
            'budget_range': (18000, 36000),
            'preferences': {
                'accommodation_type': 'Zooside Bungalow',
                'food_preference': 'North Indian Flavors'
            }
        }
    ]
}

# %%
adventure_destinations = {
    ('Adventure', 'international', 'Hiking', 'Flight'): [
        {
            'destination': 'Appalachian Trail, USA',
            'budget_range': (50000, 100000),
            'preferences': {
                'accommodation_type': 'Trailside Camping',
                'food_preference': 'Trail Mix and Energy Bars'
            }
        },
        {
            'destination': 'Inca Trail, Peru',
            'budget_range': (55000, 110000),
            'preferences': {
                'accommodation_type': 'Machu Picchu Camp',
                'food_preference': 'Peruvian Cuisine'
            }
        },
        {
            'destination': 'Torres del Paine, Chile',
            'budget_range': (60000, 120000),
            'preferences': {
                'accommodation_type': 'Patagonian Lodge',
                'food_preference': 'Chilean Delights'
            }
        }
    ],
    ('Adventure', 'international', 'Hiking', 'Ship'): [
        {
            'destination': 'Appalachian Trail, USA',
            'budget_range': (55000, 110000),
            'preferences': {
                'accommodation_type': 'Trailside Camping',
                'food_preference': 'Trail Mix and Energy Bars'
            }
        },
        {
            'destination': 'Inca Trail, Peru',
            'budget_range': (60000, 120000),
            'preferences': {
                'accommodation_type': 'Machu Picchu Camp',
                'food_preference': 'Peruvian Cuisine'
            }
        },
        {
            'destination': 'Torres del Paine, Chile',
            'budget_range': (65000, 130000),
            'preferences': {
                'accommodation_type': 'Patagonian Lodge',
                'food_preference': 'Chilean Delights'
            }
        }
    ],
    ('Adventure', 'international', 'Hiking', 'Flight'): [
        {
            'destination': 'Mount Kilimanjaro, Tanzania',
            'budget_range': (70000, 140000),
            'preferences': {
                'accommodation_type': 'Mountain Camp',
                'food_preference': 'Tanzanian Dishes'
            }
        },
        {
            'destination': 'Nepal Himalayas',
            'budget_range': (75000, 150000),
            'preferences': {
                'accommodation_type': 'Teahouse Trekking',
                'food_preference': 'Nepali Cuisine'
            }
        },
        {
            'destination': 'Haute Route, France-Switzerland',
            'budget_range': (80000, 160000),
            'preferences': {
                'accommodation_type': 'Alpine Hut',
                'food_preference': 'French and Swiss Delicacies'
            }
        }
    ],
    ('Adventure', 'national', 'Water Sports', 'Flight'): [
        {
            'destination': 'Queenstown, New Zealand',
            'budget_range': (60000, 120000),
            'preferences': {
                'accommodation_type': 'Lakefront Resort',
                'food_preference': 'New Zealand Cuisine'
            }
        },
        {
            'destination': 'Costa Rica',
            'budget_range': (65000, 130000),
            'preferences': {
                'accommodation_type': 'Beachside Villa',
                'food_preference': 'Costa Rican Flavors'
            }
        },
        {
            'destination': 'The Maldives',
            'budget_range': (70000, 140000),
            'preferences': {
                'accommodation_type': 'Overwater Bungalow',
                'food_preference': 'Maldivian Seafood'
            }
        },
        {
            'destination': 'Bali, Indonesia',
            'budget_range': (55000, 110000),
            'preferences': {
                'accommodation_type': 'Surfside Cottage',
                'food_preference': 'Indonesian Cuisine'
            }
        },
        {
            'destination': 'Fiji',
            'budget_range': (60000, 120000),
            'preferences': {
                'accommodation_type': 'Island Resort',
                'food_preference': 'Fijian Specialties'
            }
        },
        {
            'destination': 'Maui, Hawaii',
            'budget_range': (65000, 130000),
            'preferences': {
                'accommodation_type': 'Beachfront B&B',
                'food_preference': 'Hawaiian Luau Feast'
            }
        }
    ]
}

# %%
beach_destinations = {
    ('Beaches', 'national', 'White sand', 'Flight'): [
        {
            'destination': 'Radhanagar Beach, Andaman Nicobar Islands',
            'budget_range': (50000, 100000),
            'preferences': {
                'accommodation_type': 'Beachfront Resort',
                'food_preference': 'Seafood and Tropical Delights'
            }
        },
        {
            'destination': 'Varca Beach, Goa',
            'budget_range': (55000, 110000),
            'preferences': {
                'accommodation_type': 'Beachside Villa',
                'food_preference': 'Goan Cuisine'
            }
        },
        {
            'destination': 'Varkala Beach, Kerala',
            'budget_range': (60000, 120000),
            'preferences': {
                'accommodation_type': 'Cliffside Cottage',
                'food_preference': 'Kerala Specialties'
            }
        },
        {
            'destination': 'Malpe Beach, Karnataka',
            'budget_range': (55000, 110000),
            'preferences': {
                'accommodation_type': 'Beachfront Resort',
                'food_preference': 'Coastal Karnataka Food'
            }
        },
        {
            'destination': 'Ganapatipule, Maharashtra',
            'budget_range': (50000, 100000),
            'preferences': {
                'accommodation_type': 'Beachside Hut',
                'food_preference': 'Malvani Delicacies'
            }
        }
    ],
    ('Beaches', 'national', 'White sand', 'Car/Bus'): [
        {
            'destination': 'Radhanagar Beach, Andaman Nicobar Islands',
            'budget_range': (45000, 90000),
            'preferences': {
                'accommodation_type': 'Beachfront Resort',
                'food_preference': 'Seafood and Tropical Delights'
            }
        },
        {
            'destination': 'Varca Beach, Goa',
            'budget_range': (50000, 100000),
            'preferences': {
                'accommodation_type': 'Beachside Villa',
                'food_preference': 'Goan Cuisine'
            }
        },
        {
            'destination': 'Varkala Beach, Kerala',
            'budget_range': (55000, 110000),
            'preferences': {
                'accommodation_type': 'Cliffside Cottage',
                'food_preference': 'Kerala Specialties'
            }
        },
        {
            'destination': 'Malpe Beach, Karnataka',
            'budget_range': (50000, 100000),
            'preferences': {
                'accommodation_type': 'Beachfront Resort',
                'food_preference': 'Coastal Karnataka Food'
            }
        },
        {
            'destination': 'Ganapatipule, Maharashtra',
            'budget_range': (45000, 90000),
            'preferences': {
                'accommodation_type': 'Beachside Hut',
                'food_preference': 'Malvani Delicacies'
            }
        }
    ],
    ('Beaches', 'national', 'White sand', 'Railways'): [
        {
            'destination': 'Radhanagar Beach, Andaman Nicobar Islands',
            'budget_range': (48000, 96000),
            'preferences': {
                'accommodation_type': 'Beachfront Resort',
                'food_preference': 'Seafood and Tropical Delights'
            }
        },
        {
            'destination': 'Varca Beach, Goa',
            'budget_range': (52000, 104000),
            'preferences': {
                'accommodation_type': 'Beachside Villa',
                'food_preference': 'Goan Cuisine'
            }
        },
        {
            'destination': 'Varkala Beach, Kerala',
            'budget_range': (56000, 112000),
            'preferences': {
                'accommodation_type': 'Cliffside Cottage',
                'food_preference': 'Kerala Specialties'
            }
        },
        {
            'destination': 'Malpe Beach, Karnataka',
            'budget_range': (52000, 104000),
            'preferences': {
                'accommodation_type': 'Beachfront Resort',
                'food_preference': 'Coastal Karnataka Food'
            }
        },
        {
            'destination': 'Ganapatipule, Maharashtra',
            'budget_range': (48000, 96000),
            'preferences': {
                'accommodation_type': 'Beachside Hut',
                'food_preference': 'Malvani Delicacies'
            }
        }
    ],
    ('Beaches', 'international', 'White sand', 'Flight'): [
        {
            'destination': 'Hyams Beach in New South Wales, Australia',
            'budget_range': (70000, 140000),
            'preferences': {
                'accommodation_type': 'Beachfront Resort',
                'food_preference': 'Australian Seafood'
            }
        },
        {
            'destination': 'Navagio Beach in Zakynthos, Greece',
            'budget_range': (75000, 150000),
            'preferences': {
                'accommodation_type': 'Cliffside Villa',
                'food_preference': 'Greek Cuisine'
            }
        },
        {
            'destination': 'Kaunaoa Bay in Hawaii, USA',
            'budget_range': (80000, 160000),
            'preferences': {
                'accommodation_type': 'Beachfront Bungalow',
                'food_preference': 'Hawaiian Luau Feast'
            }
        }
    ],
    ('Beaches', 'international', 'White sand', 'Ship'): [
        {
            'destination': 'Hyams Beach in New South Wales, Australia',
            'budget_range': (75000, 150000),
            'preferences': {
                'accommodation_type': 'Beachfront Resort',
                'food_preference': 'Australian Seafood'
            }
        },
        {
            'destination': 'Navagio Beach in Zakynthos, Greece',
            'budget_range': (80000, 160000),
            'preferences': {
                'accommodation_type': 'Cliffside Villa',
                'food_preference': 'Greek Cuisine'
            }
        },
        {
            'destination': 'Kaunaoa Bay in Hawaii, USA',
            'budget_range': (85000, 170000),
            'preferences': {
                'accommodation_type': 'Beachfront Bungalow',
                'food_preference': 'Hawaiian Luau Feast'
            }
        }
    ],
    ('Beaches', 'national', 'Black sand', 'Flight'): [
        {
            'destination': 'Tilmati Beach, Karnataka',
            'budget_range': (55000, 110000),
            'preferences': {
                'accommodation_type': 'Seaside Cottage',
                'food_preference': 'Local Karnataka Cuisine'
            }
        },
        {
            'destination': 'Kovalam Beach, Karnataka',
            'budget_range': (60000, 120000),
            'preferences': {
                'accommodation_type': 'Beachfront Resort',
                'food_preference': 'Coastal Karnataka Food'
            }
        }
    ],
    ('Beaches', 'national', 'Black sand', 'Railways'): [
        {
            'destination': 'Tilmati Beach, Karnataka',
            'budget_range': (58000, 116000),
            'preferences': {
                'accommodation_type': 'Seaside Cottage',
                'food_preference': 'Local Karnataka Cuisine'
            }
        },
        {
            'destination': 'Kovalam Beach, Karnataka',
            'budget_range': (62000, 124000),
            'preferences': {
                'accommodation_type': 'Beachfront Resort',
                'food_preference': 'Coastal Karnataka Food'
            }
        }
    ],
    ('Beaches', 'international', 'Black sand', 'Flight'): [
        {
            'destination': 'Lafayette Beach, Tahiti',
            'budget_range': (70000, 140000),
            'preferences': {
                'accommodation_type': 'Overwater Bungalow',
                'food_preference': 'Tahitian Cuisine'
            }
        },
        {
            'destination': 'Playa Jardín, Canary Islands',
            'budget_range': (75000, 150000),
            'preferences': {
                'accommodation_type': 'Beachside Villa',
                'food_preference': 'Spanish Delights'
            }
        },
        {
            'destination': 'Punalu Beach, Hawaii',
            'budget_range': (80000, 160000),
            'preferences': {
                'accommodation_type': 'Beachfront Cottage',
                'food_preference': 'Hawaiian Luau Feast'
            }
        }
    ],
    ('Beaches', 'international', 'Urban beaches', 'Flight'): [
        {
            'destination': 'Ipanema, Rio De Janeiro',
            'budget_range': (70000, 140000),
            'preferences': {
                'accommodation_type': 'Beachfront Hotel',
                'food_preference': 'Brazilian Cuisine'
            }
        },
        {
            'destination': 'Miami Beach, USA',
            'budget_range': (75000, 150000),
            'preferences': {
                'accommodation_type': 'Art Deco Hotel',
                'food_preference': 'American Classics'
            }
        },
        {
            'destination': 'Barceloneta Beach, Barcelona',
            'budget_range': (80000, 160000),
            'preferences': {
                'accommodation_type': 'Beachfront Apartment',
                'food_preference': 'Spanish Tapas'
            }
        }
    ],
    ('Beaches', 'national', 'Urban beaches', 'Flight'): [
        {
            'destination': 'Juhu Beach, Mumbai',
            'budget_range': (50000, 100000),
            'preferences': {
                'accommodation_type': 'Beachside Hotel',
                'food_preference': 'Indian Street Food'
            }
        },
        {
            'destination': 'Marina Beach, Chennai',
            'budget_range': (55000, 110000),
            'preferences': {
                'accommodation_type': 'Seaside Resort',
                'food_preference': 'South Indian Cuisine'
            }
        },
        {
            'destination': 'Sea Beach, Puri',
            'budget_range': (60000, 120000),
            'preferences': {
                'accommodation_type': 'Beachfront Cottage',
                'food_preference': 'Odia Delicacies'
            }
        }
    ],
    ('Beaches', 'national', 'Urban beaches', 'Railways'): [
        {
            'destination': 'Juhu Beach, Mumbai',
            'budget_range': (52000, 104000),
            'preferences': {
                'accommodation_type': 'Beachside Hotel',
                'food_preference': 'Indian Street Food'
            }
        },
        {
            'destination': 'Marina Beach, Chennai',
            'budget_range': (57000, 114000),
            'preferences': {
                'accommodation_type': 'Seaside Resort',
                'food_preference': 'South Indian Cuisine'
            }
        },
        {
            'destination': 'Sea Beach, Puri',
            'budget_range': (62000, 124000),
            'preferences': {
                'accommodation_type': 'Beachfront Cottage',
                'food_preference': 'Odia Delicacies'
            }
        }
    ],
    ('Beaches', 'international', 'Pink sand', 'Flight'): [
        {
            'destination': 'Elafonissi Beach, Crete, Greece',
            'budget_range': (75000, 150000),
            'preferences': {
                'accommodation_type': 'Beachfront Villa',
                'food_preference': 'Greek Cuisine'
            }
        },
        {
            'destination': 'Pink Sands Beach, Harbour Island, Bahamas',
            'budget_range': (80000, 160000),
            'preferences': {
                'accommodation_type': 'Beachside Bungalow',
                'food_preference': 'Bahamian Delights'
            }
        },
        {
            'destination': 'Balos Beach, Crete, Greece',
            'budget_range': (85000, 170000),
            'preferences': {
                'accommodation_type': 'Cliffside Suite',
                'food_preference': 'Mediterranean Cuisine'
            }
        },
        {
            'destination': 'Horseshoe Bay Beach, Bermuda',
            'budget_range': (90000, 180000),
            'preferences': {
                'accommodation_type': 'Beachfront Cottage',
                'food_preference': 'Bermudian Specialties'
            }
        },
        {
            'destination': 'Komodo Island, Indonesia',
            'budget_range': (95000, 190000),
            'preferences': {
                'accommodation_type': 'Beachside Lodge',
                'food_preference': 'Indonesian Flavors'
            }
        }
    ],
    ('Beaches', 'international', 'Pink sand', 'Ship'): [
        {
            'destination': 'Horseshoe Bay Beach, Bermuda',
            'budget_range': (95000, 190000),
            'preferences': {
                'accommodation_type': 'Beachfront Cottage',
                'food_preference': 'Bermudian Specialties'
            }
        },
        {
            'destination': 'Komodo Island, Indonesia',
            'budget_range': (100000, 200000),
            'preferences': {
                'accommodation_type': 'Beachside Lodge',
                'food_preference': 'Indonesian Flavors'
            }
        }
    ],
    ('Beaches', 'national', 'Hidden gems', 'Flight'): [
        {
            'destination': 'Butterfly Beach, Goa',
            'budget_range': (45000, 90000),
            'preferences': {
                'accommodation_type': 'Secluded Beach Hut',
                'food_preference': 'Goan Delicacies'
            }
        },
        {
            'destination': 'Radhanagar Beach, Andaman Nicobar Islands',
            'budget_range': (50000, 100000),
            'preferences': {
                'accommodation_type': 'Beachfront Resort',
                'food_preference': 'Seafood and Tropical Delights'
            }
        },
        {
            'destination': 'Tarkarli Beach, Maharashtra',
            'budget_range': (48000, 96000),
            'preferences': {
                'accommodation_type': 'Beachside Cottage',
                'food_preference': 'Malvani Cuisine'
            }
        }
    ],
    ('Beaches', 'national', 'Hidden gems', 'Railways'): [
        {
            'destination': 'Butterfly Beach, Goa',
            'budget_range': (48000, 96000),
            'preferences': {
                'accommodation_type': 'Secluded Beach Hut',
                'food_preference': 'Goan Delicacies'
            }
        },
        {
            'destination': 'Radhanagar Beach, Andaman Nicobar Islands',
            'budget_range': (52000, 104000),
            'preferences': {
                'accommodation_type': 'Beachfront Resort',
                'food_preference': 'Seafood and Tropical Delights'
            }
        },
        {
            'destination': 'Tarkarli Beach, Maharashtra',
            'budget_range': (50000, 100000),
            'preferences': {
                'accommodation_type': 'Beachside Cottage',
                'food_preference': 'Malvani Cuisine'
            }
        }
    ],
    ('Beaches', 'national', 'Hidden gems', 'Car/Bus'): [
        {
            'destination': 'Butterfly Beach, Goa',
            'budget_range': (46000, 92000),
            'preferences': {
                'accommodation_type': 'Secluded Beach Hut',
                'food_preference': 'Goan Delicacies'
            }
        },
        {
            'destination': 'Radhanagar Beach, Andaman Nicobar Islands',
            'budget_range': (50000, 100000),
            'preferences': {
                'accommodation_type': 'Beachfront Resort',
                'food_preference': 'Seafood and Tropical Delights'
            }
        },
        {
            'destination': 'Tarkarli Beach, Maharashtra',
            'budget_range': (48000, 96000),
            'preferences': {
                'accommodation_type': 'Beachside Cottage',
                'food_preference': 'Malvani Cuisine'
            }
        }
    ],
    ('Beaches', 'international', 'Hidden gems', 'Flight'): [
        {
            'destination': 'Koh Rong, Cambodia',
            'budget_range': (70000, 140000),
            'preferences': {
                'accommodation_type': 'Beachfront Bungalow',
                'food_preference': 'Cambodian Flavors'
            }
        },
        {
            'destination': 'To Sua Ocean Trench, Samoa',
            'budget_range': (75000, 150000),
            'preferences': {
                'accommodation_type': 'Cliffside Villa',
                'food_preference': 'Samoan Cuisine'
            }
        },
        {
            'destination': 'Anse Source d\'Argent, Seychelles',
            'budget_range': (80000, 160000),
            'preferences': {
                'accommodation_type': 'Beachfront Chalet',
                'food_preference': 'Seychellois Delights'
            }
        }
    ]
}

# %%
cultural_destinations = {
    ('Cultural', 'national', 'Historical Sites', 'Flight'): [
        {
            'destination': 'Qutub Minar',
            'budget_range': (30000, 60000),
            'preferences': {
                'accommodation_type': 'Heritage Hotel',
                'food_preference': 'Indian Cuisine'
            }
        },
        {
            'destination': 'Machu Picchu, Peru',
            'budget_range': (90000, 180000),
            'preferences': {
                'accommodation_type': 'Lodge in the Andes',
                'food_preference': 'Peruvian Dishes'
            }
        },
        {
            'destination': 'Taj Mahal, Agra',
            'budget_range': (35000, 70000),
            'preferences': {
                'accommodation_type': 'Mughal-inspired Hotel',
                'food_preference': 'Mughlai Cuisine'
            }
        }
    ],
    ('Cultural', 'national', 'Historical Sites', 'Car/Bus'): [
        {
            'destination': 'Qutub Minar',
            'budget_range': (25000, 50000),
            'preferences': {
                'accommodation_type': 'Heritage Hotel',
                'food_preference': 'Indian Cuisine'
            }
        },
        {
            'destination': 'Machu Picchu, Peru',
            'budget_range': (85000, 170000),
            'preferences': {
                'accommodation_type': 'Lodge in the Andes',
                'food_preference': 'Peruvian Dishes'
            }
        },
        {
            'destination': 'Taj Mahal, Agra',
            'budget_range': (30000, 60000),
            'preferences': {
                'accommodation_type': 'Mughal-inspired Hotel',
                'food_preference': 'Mughlai Cuisine'
            }
        }
    ],
    ('Cultural', 'national', 'Historical Sites', 'Railways'): [
        {
            'destination': 'Qutub Minar',
            'budget_range': (28000, 56000),
            'preferences': {
                'accommodation_type': 'Heritage Hotel',
                'food_preference': 'Indian Cuisine'
            }
        },
        {
            'destination': 'Machu Picchu, Peru',
            'budget_range': (88000, 176000),
            'preferences': {
                'accommodation_type': 'Lodge in the Andes',
                'food_preference': 'Peruvian Dishes'
            }
        },
        {
            'destination': 'Taj Mahal, Agra',
            'budget_range': (32000, 64000),
            'preferences': {
                'accommodation_type': 'Mughal-inspired Hotel',
                'food_preference': 'Mughlai Cuisine'
            }
        }
    ],
    ('Cultural', 'international', 'Historical Sites', 'Flight'): [
        {
            'destination': 'Great Wall of China, China',
            'budget_range': (60000, 120000),
            'preferences': {
                'accommodation_type': 'Chinese Courtyard Hotel',
                'food_preference': 'Chinese Cuisine'
            }
        },
        {
            'destination': 'The Colosseum, Italy',
            'budget_range': (70000, 140000),
            'preferences': {
                'accommodation_type': 'Roman-style Villa',
                'food_preference': 'Italian Delicacies'
            }
        },
        {
            'destination': 'Pyramids of Giza, Egypt',
            'budget_range': (80000, 160000),
            'preferences': {
                'accommodation_type': 'Desert Oasis Resort',
                'food_preference': 'Egyptian Food'
            }
        },
        {
            'destination': 'Acropolis of Athens, Greece',
            'budget_range': (75000, 150000),
            'preferences': {
                'accommodation_type': 'Greek-inspired Hotel',
                'food_preference': 'Greek Cuisine'
            }
        }
    ],
    ('Cultural', 'international', 'Art and Museums', 'Flight'): [
        {
            'destination': 'Louvre Museum, Paris',
            'budget_range': (80000, 160000),
            'preferences': {
                'accommodation_type': 'Art-themed Hotel',
                'food_preference': 'French Cuisine'
            }
        },
        {
            'destination': 'British Museum, London',
            'budget_range': (75000, 150000),
            'preferences': {
                'accommodation_type': 'Classic British Inn',
                'food_preference': 'British Classics'
            }
        },
        {
            'destination': 'The Met, New York',
            'budget_range': (85000, 170000),
            'preferences': {
                'accommodation_type': 'Art-lover\'s Retreat',
                'food_preference': 'International Gastronomy'
            }
        }
    ],
    ('Cultural', 'international', 'Art and Museums', 'Ship'): [
        {
            'destination': 'Louvre Museum, Paris',
            'budget_range': (85000, 170000),
            'preferences': {
                'accommodation_type': 'Art-themed Hotel',
                'food_preference': 'French Cuisine'
            }
        },
        {
            'destination': 'British Museum, London',
            'budget_range': (80000, 160000),
            'preferences': {
                'accommodation_type': 'Classic British Inn',
                'food_preference': 'British Classics'
            }
        },
        {
            'destination': 'The Met, New York',
            'budget_range': (90000, 180000),
            'preferences': {
                'accommodation_type': 'Art-lover\'s Retreat',
                'food_preference': 'International Gastronomy'
            }
        },
        {
            'destination': 'The Vatican Museums, Vatican City',
            'budget_range': (95000, 190000),
            'preferences': {
                'accommodation_type': 'Historical Residence',
                'food_preference': 'Italian Cuisine'
            }
        },
        {
            'destination': 'The Hermitage, Russia',
            'budget_range': (95000, 190000),
            'preferences': {
                'accommodation_type': 'Cultural Stay',
                'food_preference': 'Russian Fare'
            }
        },
        {
            'destination': 'Prado Museum, Spain',
            'budget_range': (90000, 180000),
            'preferences': {
                'accommodation_type': 'Spanish-style Lodging',
                'food_preference': 'Spanish Tapas'
            }
        }
    ]
}

# %%
nature_wildlife_destinations = {
    ('Nature', 'national', 'Wildlife Safaris', 'Flight'): [
        {
            'destination': 'Ranthambore National Park, India',
            'budget_range': (40000, 80000),
            'preferences': {
                'accommodation_type': 'Wildlife Lodge',
                'food_preference': 'Indian Cuisine'
            }
        }
    ],
    ('Nature', 'international', 'Wildlife Safaris', 'Flight'): [
        {
            'destination': 'Kruger National Park, South Africa',
            'budget_range': (80000, 160000),
            'preferences': {
                'accommodation_type': 'Safari Lodge',
                'food_preference': 'African Cuisine'
            }
        },
        {
            'destination': 'Amazon Rainforest, Brazil',
            'budget_range': (90000, 180000),
            'preferences': {
                'accommodation_type': 'Eco-friendly Jungle Lodge',
                'food_preference': 'Local Amazonian Food'
            }
        },
        {
            'destination': 'Galapagos Islands, Ecuador',
            'budget_range': (95000, 190000),
            'preferences': {
                'accommodation_type': 'Island Resort',
                'food_preference': 'Fresh Seafood'
            }
        },
        {
            'destination': 'Serengeti National Park, Tanzania',
            'budget_range': (85000, 170000),
            'preferences': {
                'accommodation_type': 'Safari Camp',
                'food_preference': 'African Dishes'
            }
        },
        {
            'destination': 'Yellowstone National Park, USA',
            'budget_range': (75000, 150000),
            'preferences': {
                'accommodation_type': 'Rustic Lodge',
                'food_preference': 'American Cuisine'
            }
        }
    ],
    ('Nature', 'international', 'Natural Wonders', 'Ship'): [
        {
            'destination': 'Grand Canyon, USA',
            'budget_range': (80000, 160000),
            'preferences': {
                'accommodation_type': 'Canyon-side Resort',
                'food_preference': 'American Cuisine'
            }
        },
        {
            'destination': 'Ayers Rock (Uluru), Australia',
            'budget_range': (90000, 180000),
            'preferences': {
                'accommodation_type': 'Outback Retreat',
                'food_preference': 'Australian Fare'
            }
        },
        {
            'destination': 'Victoria Falls, Zambia/Zimbabwe',
            'budget_range': (85000, 170000),
            'preferences': {
                'accommodation_type': 'Riverfront Lodge',
                'food_preference': 'African Cuisine'
            }
        }
    ],
    ('Nature', 'international', 'Natural Wonders', 'Flight'): [
        {
            'destination': 'Aurora Borealis (Northern Lights), Iceland',
            'budget_range': (95000, 190000),
            'preferences': {
                'accommodation_type': 'Igloo Hotel',
                'food_preference': 'Nordic Delicacies'
            }
        },
        {
            'destination': 'Mount Everest Base Camp, Nepal',
            'budget_range': (90000, 180000),
            'preferences': {
                'accommodation_type': 'Base Camp Lodge',
                'food_preference': 'Nepali Cuisine'
            }
        },
        {
            'destination': 'Santorini, Greece',
            'budget_range': (85000, 170000),
            'preferences': {
                'accommodation_type': 'Cliffside Villa',
                'food_preference': 'Greek Cuisine'
            }
        }
    ]
}

# %%
wellness_spa_destinations = {
    ('Wellness', 'international', 'Spa Retreats', 'Flight'): [
        {
            'destination': 'The Ranch Malibu, California',
            'budget_range': (120000, 240000),
            'preferences': {
                'accommodation_type': 'Luxury Spa Resort',
                'food_preference': 'Healthy Cuisine'
            }
        },
        {
            'destination': 'Blue Lagoon, Iceland',
            'budget_range': (140000, 280000),
            'preferences': {
                'accommodation_type': 'Geothermal Spa Hotel',
                'food_preference': 'Icelandic Delicacies'
            }
        }
    ],
    ('Wellness', 'national', 'Spa Retreats', 'Car/Bus'): [
        {
            'destination': 'Ananda in the Himalayas, India',
            'budget_range': (80000, 160000),
            'preferences': {
                'accommodation_type': 'Ayurvedic Wellness Retreat',
                'food_preference': 'Indian Ayurvedic Cuisine'
            }
        },
        {
            'destination': 'Rishikesh, India',
            'budget_range': (75000, 150000),
            'preferences': {
                'accommodation_type': 'Yoga Ashram',
                'food_preference': 'Vegetarian Sattvic Food'
            }
        }
    ],
    ('Wellness', 'national', 'Spa Retreats', 'Railways'): [
        {
            'destination': 'Ananda in the Himalayas, India',
            'budget_range': (80000, 160000),
            'preferences': {
                'accommodation_type': 'Ayurvedic Wellness Retreat',
                'food_preference': 'Indian Ayurvedic Cuisine'
            }
        },
        {
            'destination': 'Rishikesh, India',
            'budget_range': (75000, 150000),
            'preferences': {
                'accommodation_type': 'Yoga Ashram',
                'food_preference': 'Vegetarian Sattvic Food'
            }
        }
    ],
    ('Wellness', 'international', 'Spa Retreats', 'Flight'): [
        {
            'destination': 'SHA Wellness Clinic, Spain',
            'budget_range': (150000, 300000),
            'preferences': {
                'accommodation_type': 'Medical Spa Resort',
                'food_preference': 'Wellness Cuisine'
            }
        },
        {
            'destination': 'Kamalaya, Thailand',
            'budget_range': (140000, 280000),
            'preferences': {
                'accommodation_type': 'Holistic Wellness Retreat',
                'food_preference': 'Thai Wellness Cuisine'
            }
        },
        {
            'destination': 'Aro Hā, New Zealand',
            'budget_range': (160000, 320000),
            'preferences': {
                'accommodation_type': 'Eco-Friendly Wellness Retreat',
                'food_preference': 'Organic Plant-Based Food'
            }
        }
    ],
    ('Wellness', 'international', 'Spa Retreats', 'Ship'): [
        {
            'destination': 'SHA Wellness Clinic, Spain',
            'budget_range': (160000, 320000),
            'preferences': {
                'accommodation_type': 'Medical Spa Resort',
                'food_preference': 'Wellness Cuisine'
            }
        },
        {
            'destination': 'Kamalaya, Thailand',
            'budget_range': (150000, 300000),
            'preferences': {
                'accommodation_type': 'Holistic Wellness Retreat',
                'food_preference': 'Thai Wellness Cuisine'
            }
        },
        {
            'destination': 'Aro Hā, New Zealand',
            'budget_range': (170000, 340000),
            'preferences': {
                'accommodation_type': 'Eco-Friendly Wellness Retreat',
                'food_preference': 'Organic Plant-Based Food'
            }
        }
    ],
    ('Wellness', 'international', 'Yoga Retreats', 'Ship'): [
        {
            'destination': 'Ubud, Bali',
            'budget_range': (100000, 200000),
            'preferences': {
                'accommodation_type': 'Yoga Retreat Center',
                'food_preference': 'Balinese Cuisine'
            }
        },
        {
            'destination': 'Tulum, Mexico',
            'budget_range': (110000, 220000),
            'preferences': {
                'accommodation_type': 'Beachfront Yoga Retreat',
                'food_preference': 'Mexican Vegan Food'
            }
        }
    ],
    ('Wellness', 'international', 'Yoga Retreats', 'Flight'): [
        {
            'destination': 'Ubud, Bali',
            'budget_range': (120000, 240000),
            'preferences': {
                'accommodation_type': 'Yoga Retreat Center',
                'food_preference': 'Balinese Cuisine'
            }
        },
        {
            'destination': 'Big Sur, California',
            'budget_range': (140000, 280000),
            'preferences': {
                'accommodation_type': 'Coastal Yoga Retreat',
                'food_preference': 'California Fresh'
            }
        },
        {
            'destination': 'Bhutan Himalayas',
            'budget_range': (150000, 300000),
            'preferences': {
                'accommodation_type': 'Mountain Yoga Retreat',
                'food_preference': 'Bhutanese Cuisine'
            }
        },
        {
            'destination': 'Santorini, Greece',
            'budget_range': (160000, 320000),
            'preferences': {
                'accommodation_type': 'Island Yoga Retreat',
                'food_preference': 'Greek Mediterranean'
            }
        }
    ]
}

# %%
food_culinary_destinations = {
    ('Food', 'international', 'Culinary Capitals', 'Ship'): [
        {
            'destination': 'Paris, France',
            'budget_range': (180000, 360000),
            'preferences': {
                'cuisine_type': 'French Cuisine',
                'food_experience': 'Fine Dining'
            }
        },
        {
            'destination': 'Tokyo, Japan',
            'budget_range': (200000, 400000),
            'preferences': {
                'cuisine_type': 'Japanese Cuisine',
                'food_experience': 'Sushi and Ramen'
            }
        },
        {
            'destination': 'Bangkok, Thailand',
            'budget_range': (160000, 320000),
            'preferences': {
                'cuisine_type': 'Thai Cuisine',
                'food_experience': 'Street Food'
            }
        }
    ],
    ('Food', 'international', 'Culinary Capitals', 'Flight'): [
        {
            'destination': 'Paris, France',
            'budget_range': (200000, 400000),
            'preferences': {
                'cuisine_type': 'French Cuisine',
                'food_experience': 'Fine Dining'
            }
        },
        {
            'destination': 'New York City, USA',
            'budget_range': (220000, 440000),
            'preferences': {
                'cuisine_type': 'American Cuisine',
                'food_experience': 'Diverse Food Scene'
            }
        },
        {
            'destination': 'Barcelona, Spain',
            'budget_range': (180000, 360000),
            'preferences': {
                'cuisine_type': 'Spanish Cuisine',
                'food_experience': 'Tapas and Paella'
            }
        },
        {
            'destination': 'Istanbul, Turkey',
            'budget_range': (160000, 320000),
            'preferences': {
                'cuisine_type': 'Turkish Cuisine',
                'food_experience': 'Kebabs and Baklava'
            }
        }
    ],
    ('Food', 'international', 'Street Food', 'Flight'): [
        {
            'destination': 'Penang, Malaysia',
            'budget_range': (120000, 240000),
            'preferences': {
                'cuisine_type': 'Malaysian Street Food',
                'food_experience': 'Hawker Stalls'
            }
        },
        {
            'destination': 'Marrakech, Morocco',
            'budget_range': (140000, 280000),
            'preferences': {
                'cuisine_type': 'Moroccan Street Food',
                'food_experience': 'Souks and Spices'
            }
        },
        {
            'destination': 'Ho Chi Minh City, Vietnam',
            'budget_range': (110000, 220000),
            'preferences': {
                'cuisine_type': 'Vietnamese Street Food',
                'food_experience': 'Pho and Banh Mi'
            }
        },
        {
            'destination': 'Mexico City, Mexico',
            'budget_range': (130000, 260000),
            'preferences': {
                'cuisine_type': 'Mexican Street Food',
                'food_experience': 'Tacos and Tamales'
            }
        },
        {
            'destination': 'Istanbul, Turkey',
            'budget_range': (120000, 240000),
            'preferences': {
                'cuisine_type': 'Turkish Street Food',
                'food_experience': 'Kebabs and Baklava'
            }
        }
    ],
    ('Food', 'national', 'Street Food', 'Car/Bus'): [
        {
            'destination': 'Bangalore, India',
            'budget_range': (40000, 80000),
            'preferences': {
                'cuisine_type': 'Indian Street Food',
                'food_experience': 'Spicy Delights'
            }
        }
    ],
    ('Food', 'national', 'Street Food', 'Railways'): [
        {
            'destination': 'Bangalore, India',
            'budget_range': (40000, 80000),
            'preferences': {
                'cuisine_type': 'Indian Street Food',
                'food_experience': 'Spicy Delights'
            }
        }
    ],
    ('Food', 'national', 'Street Food', 'Flight'): [
        {
            'destination': 'Bangalore, India',
            'budget_range': (40000, 80000),
            'preferences': {
                'cuisine_type': 'Indian Street Food',
                'food_experience': 'Spicy Delights'
            }
        }
    ]
}

# %%
# Religious Destinations
areligious_destinations = {
    ('Religious', 'national', 'Hindu', 'Car/bus'): ['Somnath Temple, Gujarat', 'Kedarnath, Uttrakhand', 'Vishvanath Temple, Varanasi'],
    ('Religious', 'national', 'Hindu', 'Railways'): ['Somnath Temple, Gujarat', 'Kedarnath, Uttrakhand', 'Vishvanath Temple, Varanasi'],
    ('Religious', 'national', 'Hindu', 'Flight'): ['Somnath Temple, Gujarat', 'Kedarnath, Uttrakhand', 'Vishvanath Temple, Varanasi'],
    ('Religious', 'national', 'Islamic','Car/bus' ): ['Hazratbal Shrine Srinagar', 'Haji Ali Dargah, Mumbai', 'Ajmer Sharif, Ajmer, Rajasthan'],
    ('Religious', 'national', 'Islamic','Railways' ): ['Hazratbal Shrine Srinagar', 'Haji Ali Dargah, Mumbai', 'Ajmer Sharif, Ajmer, Rajasthan'],
    ('Religious', 'national', 'Islamic','Flight' ): ['Hazratbal Shrine Srinagar', 'Haji Ali Dargah, Mumbai', 'Ajmer Sharif, Ajmer, Rajasthan'],
    ('Religious', 'national', 'Sikh', 'Car/bus'): ['Golden Temple, Amritsar', 'Hemkund Sahib, Himachal Pradesh'],
    ('Religious', 'national', 'Sikh', 'Railways' ): ['Golden Temple, Amritsar', 'Hemkund Sahib, Himachal Pradesh'],
    ('Religious', 'national', 'Sikh', 'Flight'): ['Golden Temple, Amritsar', 'Hemkund Sahib, Himachal Pradesh'],
    ('Religious', 'national', 'Jainism', 'Car/bus'): ['Dilwara Temple, Mount Abu', 'Ranakpur Jain Temple, Ranakpur', 'Palitana Temples, Bhavnagar District (Gujarat)'],
    ('Religious', 'national', 'Jainism', 'Railways'): ['Dilwara Temple, Mount Abu', 'Ranakpur Jain Temple, Ranakpur', 'Palitana Temples, Bhavnagar District (Gujarat)'],
    ('Religious', 'international', 'Buddhist', 'Flight'): ['Lumbini, Nepal'],
    ('Religious', 'international', 'Christian', 'Flight'): ['Vatican City', 'Jerusalem', 'Lourdes, France'],
    ('Religious', 'international', 'Christian', 'Ship'): ['Vatican City', 'Jerusalem', 'Lourdes, France']

}

# Camping Destinations
acamping_destinations = {
    ('Camping', 'international', 'Tent Camping', 'Flight'): ['Dry Tortugas National Park, Florida', 'Minnewaska State Park Reserve, New York'],
    ('Camping', 'national', 'Tent Camping', 'Car/Bus'): ['Camp Mustang, Sohna Road', 'Damdama Lake, Gurgaon', 'Camp Tikkling, Gurgaon'],
    ('Camping', 'national', 'Glamping', 'Car/Bus'): ['Sherbagh, Ranthambore', 'Tree House Resort, Jaipur', 'Serai, Jaisalmer'],
    ('Camping', 'national', 'Glamping', 'Railways'): ['Sherbagh, Ranthambore', 'Tree House Resort, Jaipur', 'Serai, Jaisalmer'],
    ('Camping', 'international', 'Glamping', 'Flight'): ['Huttopia White Mountains, Conway', 'Dunton River Camp, Dolores', 'Firelight Camps, Ithaca'],
    ('Camping', 'international', 'Backpacking', 'Flight'): ['Unawatuna, Sri Lanka', 'Queenstown, New Zealand', 'Palawan, the Philippines'],
    ('Camping', 'international', 'Backpacking', 'Ship'): ['Unawatuna, Sri Lanka', 'Queenstown, New Zealand', 'Palawan, the Philippines'],
    ('Camping', 'international', 'RV Camping', 'Flight'): ['Yellowstone National Park, USA', 'Banff National Park, Canada', 'Great Ocean Road, Australia']
}

# Mountain Destinations
amountain_destinations = {
    ('Mountains', "national",'North',  'Car/Bus'): ['Leh, Lahaul Spiti', 'Shimla', 'Dharamshala', 'Dalhousie', 'Mussorie', 'Chamba'],
    ('Mountains', "national",'North',  'Railways'): ['Leh, Lahaul Spiti', 'Shimla', 'Dharamshala', 'Dalhousie', 'Mussorie', 'Chamba'], 
    ('Mountains', "national",'North',  'Flight'): ['Leh, Lahaul Spiti', 'Chamba'], 
    ('Mountains', "national", 'East', 'Flight'): ['Shillong', 'Pelling', 'Darjeeling', 'Tawang'],
    ('Mountains', "national", 'East', 'Car/Bus'): ['Shillong', 'Pelling', 'Darjeeling', 'Tawang'],
    ('Mountains', "national", 'East', 'Railways'): ['Shillong', 'Pelling', 'Darjeeling', 'Tawang'],
    ('Mountains', "national", 'South', 'Railways'): ['Yercaud, Tamil Nadu', 'Yelagiri, Tamil Nadu', 'Coonoor, Tamil Nadu', 'Kotagiri, Tamil Nadu'],
    ('Mountains', "national", 'South', 'Flight'): ['Yercaud, Tamil Nadu', 'Yelagiri, Tamil Nadu', 'Coonoor, Tamil Nadu', 'Kotagiri, Tamil Nadu'],
    ('Mountains', "national", 'West', 'Railways'): ['Mahabaleshwar', 'Khandala', 'Mount Abu', 'Saputara', 'Kamshet', 'Lavasa'],
    ('Mountains', "national", 'West', 'Car/Bus'): ['Mahabaleshwar', 'Khandala', 'Mount Abu', 'Saputara', 'Kamshet', 'Lavasa'],
    ('Mountains', "national", 'Himalayas', 'Railways'): ['Nepal Himalayas', 'Bhutan Himalayas', 'Karakoram Range India', 'Sikkim Himalayas'],
    ('Mountains', 'international', 'Flight'): ['Machu Picchu, Peru', 'Swiss Alps, Switzerland', 'Patagonia, Argentina']
}

# Sanctuary Destinations
asanctuary_destinations = {
    ('Sanctuaries', 'national', 'Marine', 'Car/Bus'): ['Malvan Marine Sanctuary', 'Sindhudurg, Maharashtra', 'Gahirmatha Marine Sanctuary, Odisha', 'Gulf of Mannar Marine National Park'],
    ('Sanctuaries', 'national', 'Marine', 'Railways'): ['Malvan Marine Sanctuary', 'Sindhudurg, Maharashtra', 'Gahirmatha Marine Sanctuary, Odisha', 'Gulf of Mannar Marine National Park'],
    ('Sanctuaries', 'international', 'Marine', 'Flight'): ['Channel Islands National Marine Sanctuary', 'Cordell Bank National Marine Sanctuary'],
    ('Sanctuaries', 'national', 'Areial', 'Car/Bus'): ['Najafgarh Drain Bird Sanctuary, Delhi', 'Salim Ali Bird Sanctuary, Goa', 'Gaga Wildlife Sanctuary, Gujarat', 'Khijadiya Bird Sanctuary, Gujarat'],
    ('Sanctuaries', 'national', 'Areial', 'Railways'): ['Najafgarh Drain Bird Sanctuary, Delhi', 'Salim Ali Bird Sanctuary, Goa', 'Gaga Wildlife Sanctuary, Gujarat', 'Khijadiya Bird Sanctuary, Gujarat'],
    ('Sanctuaries', 'national', 'Areial', 'Flight'): ['Najafgarh Drain Bird Sanctuary, Delhi', 'Salim Ali Bird Sanctuary, Goa', 'Gaga Wildlife Sanctuary, Gujarat', 'Khijadiya Bird Sanctuary, Gujarat'],
    ('Sanctuaries', 'international', 'Areial', 'Flight'): ['Weltvogelpark Walsrode, Germany', 'Jurong Bird Park, Singapore'],
    ('Sanctuaries', 'national', 'Terrestial', 'Car/Bus'): ['Jim Corbett National Park, Uttarakhand', 'Ranthambore National Park, Rajasthan', 'Gir National Park, Gujarat', 'Kaziranga National Park, Assam'],
    ('Sanctuaries', 'national', 'Terrestial', 'Railways'): ['Jim Corbett National Park, Uttarakhand', 'Ranthambore National Park, Rajasthan', 'Gir National Park, Gujarat', 'Kaziranga National Park, Assam'],
    ('Sanctuaries', 'national', 'Terrestial', 'Flight'): ['Jim Corbett National Park, Uttarakhand', 'Ranthambore National Park, Rajasthan', 'Gir National Park, Gujarat', 'Kaziranga National Park, Assam'],
    ('Sanctuaries', 'international', 'Terrestial', 'Flight'): ['Grand Canyon National Park, USA', 'Great Barrier Reef National Park, Australia', 'Kruger National Park, South Africa'],
    ('Sanctuaries', 'international', 'Rainforest', 'Flight'): [ 'Sinharaja Forest Reserve, Sri Lanka', 'Taman Negara National Park, Malaysia'],
    ('Sanctuaries', 'international', 'Zoo', 'Flight'): ['Tiergarten Schönbrunn, Vienna, Austria', 'Bronx Zoo, New York City, USA', 'San Diego Zoo, San Diego, USA', 'Singapore Zoo, Singapore'],
    ('Sanctuaries', 'national', 'Zoo', 'Car/Bus'): ['Nandankanan Zoological Park, Bhubaneshwar', 'Indira Gandhi Zoological Park, Andhra Pradesh', 'Allen Forest Zoo, Kanpur'],
    ('Sanctuaries1', 'national', 'Zoo', 'Railways'): ['Nandankanan Zoological Park, Bhubaneshwar', 'Indira Gandhi Zoological Park, Andhra Pradesh', 'Allen Forest Zoo, Kanpur'],
    ('Sanctuaries1', 'national', 'Zoo', 'Flight'): ['Nandankanan Zoological Park, Bhubaneshwar', 'Indira Gandhi Zoological Park, Andhra Pradesh', 'Allen Forest Zoo, Kanpur'],
}

# Beach Destinations
abeach_destinations = {
    ('Beaches', 'national', 'White sand', 'Flight'): ['Radhanagar Beach, Andaman Nicobar Islands', 'Varca Beach, Goa', 'Varkala Beach, Kerala', 'Malpe Beach, Karnataka', 'Ganapatipule, Maharashtra'],
    ('Beaches', 'national', 'White sand', 'Car/Bus'): ['Radhanagar Beach', 'Varca Beach, Goa', 'Varkala Beach, Kerala', 'Malpe Beach, Karnataka', 'Ganapatipule, Maharashtra'],
    ('Beaches', 'national', 'White sand', 'Railways'): ['Radhanagar Beach', 'Varca Beach, Goa', 'Varkala Beach, Kerala', 'Malpe Beach, Karnataka', 'Ganapatipule, Maharashtra'],
    ('Beaches', 'international', 'White sand', 'Flight'): ['Hyams Beach in New South Wales, Australia', 'Navagio Beach in Zakynthos, Greece', 'Kaunaoa Bay in Hawaii, USA'],
    ('Beaches', 'international', 'White sand', 'Ship'): ['Hyams Beach in New South Wales, Australia', 'Navagio Beach in Zakynthos, Greece', 'Kaunaoa Bay in Hawaii, USA'],
    ('Beaches', 'national', 'Black sand', 'Flight'): ['Tilmati Beach, Karnataka', 'Kovalam Beach, Karnataka'],
    ('Beaches', 'national', 'Black sand', 'Railways'): ['Tilmati Beach, Karnataka', 'Kovalam Beach, Karnataka'],
    ('Beaches', 'international', 'Black sand', 'Flight'): ['Lafayette Beach, Tahiti', 'Playa Jardín, Canary Islands', 'Punalu Beach, Hawaii'],
    ('Beaches', 'international', 'Urban beaches', 'Flight'): ['Ipanema, Rio De Janeiro', 'Miami Beach, USA', 'Barceloneta Beach, Barcelona'],
    ('Beaches', 'national', 'Urban beaches', 'Flight'): ['Juhu Beach, Mumbai', 'Marina Beach, Chennai', 'Sea Beach, Puri'],
    ('Beaches', 'national', 'Urban beaches', 'Railways'): ['Juhu Beach, Mumbai', 'Marina Beach, Chennai', 'Sea Beach, Puri'],
    ('Beaches', 'intenational', 'Pink sand', 'Flight'): ['Elafonissi Beach, Crete, Greece', 'Pink Sands Beach, Harbour Island, Bahamas', 'Balos Beach, Crete, Greece', 'Horseshoe Bay Beach, Bermuda', 'Komodo Island, Indonesia'],
    ('Beaches', 'international', 'Pink sand', 'Ship'): ['Horseshoe Bay Beach, Bermuda', 'Komodo Island, Indonesia'],
    ('Beaches', 'national', 'Hidden gems', 'Flight'): ['Butterfly Beach, Goa', 'Radhanagar Beach, Andaman Nicobar Islands', 'Tarkarli Beach, Maharashtra'],
    ('Beaches', 'national', 'Hidden gems', 'Railways'): ['Butterfly Beach, Goa', 'Radhanagar Beach, Andaman Nicobar Islands', 'Tarkarli Beach, Maharashtra'],
    ('Beaches', 'national', 'Hidden gems', 'Car/Bus'): ['Butterfly Beach, Goa', 'Radhanagar Beach, Andaman Nicobar Islands', 'Tarkarli Beach, Maharashtra'],
    ('Beaches', 'international', 'Hidden gems', 'Flight'): ['Koh Rong, Cambodia', 'To Sua Ocean Trench, Samoa', 'Anse Source d\'Argent, Seychelles']

}




# Adventure Destinations
aadventure_destinations = {
    ('Adventure', 'international', 'Hiking', 'Flight'): ['Appalachian Trail, USA', 'Inca Trail, Peru', 'Torres del Paine, Chile'],
    ('Adventure', 'international', 'Hiking', 'Ship'): ['Appalachian Trail, USA', 'Inca Trail, Peru', 'Torres del Paine, Chile'],
    ('Adventure', 'international', 'Hiking', 'Flight'): ['Mount Kilimanjaro, Tanzania', 'Nepal Himalayas', 'Haute Route, France-Switzerland'],
    ('Adventure', 'national', 'Water Sports', 'Flight'): ['Queenstown, New Zealand', 'Costa Rica', 'The Maldives', 'Bali, Indonesia', 'Fiji', 'Maui, Hawaii']
}

# Cultural Destinations
acultural_destinations = {
    ('Cultural', 'national', 'Historical Sites',  'Flight'): ['Qutub Minar', 'Machu Picchu, Peru', 'Taj Mahal, Agra'],
    ('Cultural', 'national', 'Historical Sites',  'Car/Bus'): ['Qutub Minar', 'Machu Picchu, Peru', 'Taj Mahal, Agra'],
    ('Cultural', 'national', 'Historical Sites',  'Railways'): ['Qutub Minar', 'Machu Picchu, Peru', 'Taj Mahal, Agra'],
    ('Cultural', 'international', 'Historical Sites', 'Flight'): [ 'Great Wall of China, China', 'The Colosseum, Italy', 'Pyramids of Giza, Egypt', 'Acropolis of Athens, Greece'],
    ('Cultural', 'international', 'Art and Museums', 'Flight'): ['Louvre Museum, Paris', 'British Museum, London', 'The Met, New York'],
    ('Cultural', 'international', 'Art and Museums', 'Ship'): ['Louvre Museum, Paris', 'British Museum, London', 'The Met, New York', 'The Vatican Museums, Vatican City', 'The Hermitage, Russia', 'Prado Museum, Spain'],
}

# Nature and Wildlife Destinations
anature_wildlife_destinations = {
    ('Nature', 'national', 'Wildlife Safaris', 'Flight'): ['Ranthambore National Park, India'],
    ('Nature', 'international', 'Wildlife Safaris', 'Flight'): ['Kruger National Park, South Africa', 'Amazon Rainforest, Brazil', 'Galapagos Islands, Ecuador', 'Serengeti National Park, Tanzania', 'Yellowstone National Park, USA'],
    ('Nature', 'international', 'Natural Wonders', 'Ship'): ['Grand Canyon, USA', 'Ayers Rock (Uluru), Australia', 'Victoria Falls, Zambia/Zimbabwe'],
    ('Nature', 'international', 'Natural Wonders', 'Flight'): ['Aurora Borealis (Northern Lights), Iceland', 'Mount Everest Base Camp, Nepal', 'Santorini, Greece']
}

# Wellness and Spa Destinations
awellness_spa_destinations = {
    ('Wellness', 'international', 'Spa Retreats', 'Flight'): ['The Ranch Malibu, California', 'Blue Lagoon, Iceland'],
    ('Wellness', 'national', 'Spa Retreats', 'Car/Bus') : ['Ananda in the Himalayas, India', 'Rishikesh, India'],
    ('Wellness', 'national', 'Spa Retreats', 'Railways') : ['Ananda in the Himalayas, India', 'Rishikesh, India'],
    ('Wellness', 'international', 'Spa Retreats', 'Flight'): ['SHA Wellness Clinic, Spain', 'Kamalaya, Thailand', 'Aro Hā, New Zealand'],
    ('Wellness', 'international', 'Spa Retreats', 'Ship'): ['SHA Wellness Clinic, Spain', 'Kamalaya, Thailand', 'Aro Hā, New Zealand'],
    ('Wellness', 'international', 'Yoga Retreats', 'Ship'): ['Ubud, Bali', 'Tulum, Mexico'],
    ('Wellness', 'international', 'Yoga Retreats', 'Flight'): ['Ubud, Bali', 'Big Sur, California',  'Bhutan Himalayas', 'Santorini, Greece']
}

# Food and Culinary Destinations
afood_culinary_destinations = {
    ('Food', 'international', 'Culinary Capitals', 'Ship'): ['Paris, France', 'Tokyo, Japan', 'Bangkok, Thailand'],
    ('Food', 'international', 'Culinary Capitals', 'Flight'): ['Paris, France', 'New York City, USA', 'Barcelona, Spain', 'Istanbul, Turkey'],
    ('Food', 'international', 'Street Food', 'Flight'): ['Penang, Malaysia', 'Marrakech, Morocco', 'Ho Chi Minh City, Vietnam',  'Mexico City, Mexico', 'Istanbul, Turkey'],
    ('Food', 'national', 'Street Food', 'Car/Bus') : ['Bangalore, India'],
    ('Food', 'national', 'Street Food', 'Railways') : ['Bangalore, India'],
    ('Food', 'national', 'Street Food', 'Flight') : ['Bangalore, India']

}

# %%
destination_feedback_rating = {}

# Initialize feedback, rating total, and rating count for each destination
for category, destinations in areligious_destinations.items():
    for destination in destinations:
        destination_feedback_rating[destination] = {'feedback': [], 'rating_total': 0, 'rating_count': 0}

for category, destinations in acamping_destinations.items():
    for destination in destinations:
        destination_feedback_rating[destination] = {'feedback': [], 'rating_total': 0, 'rating_count': 0}

for category, destinations in amountain_destinations.items():
    for destination in destinations:
        destination_feedback_rating[destination] = {'feedback': [], 'rating_total': 0, 'rating_count': 0}

for category, destinations in asanctuary_destinations.items():
    for destination in destinations:
        destination_feedback_rating[destination] = {'feedback': [], 'rating_total': 0, 'rating_count': 0}

for category, destinations in abeach_destinations.items():
    for destination in destinations:
        destination_feedback_rating[destination] = {'feedback': [], 'rating_total': 0, 'rating_count': 0}

for category, destinations in aadventure_destinations.items():
    for destination in destinations:
        destination_feedback_rating[destination] = {'feedback': [], 'rating_total': 0, 'rating_count': 0}

for category, destinations in acultural_destinations.items():
    for destination in destinations:
        destination_feedback_rating[destination] = {'feedback': [], 'rating_total': 0, 'rating_count': 0}

for category, destinations in anature_wildlife_destinations.items():
    for destination in destinations:
        destination_feedback_rating[destination] = {'feedback': [], 'rating_total': 0, 'rating_count': 0}

for category, destinations in awellness_spa_destinations.items():
    for destination in destinations:
        destination_feedback_rating[destination] = {'feedback': [], 'rating_total': 0, 'rating_count': 0}

for category, destinations in afood_culinary_destinations.items():
    for destination in destinations:
        destination_feedback_rating[destination] = {'feedback': [], 'rating_total': 0, 'rating_count': 0}

# Print a sample entry from the destination_feedback_rating dictionary
sample_destination = list(destination_feedback_rating.keys())[0]

# %%
# Save the dictionaries to a file
with open('destination_data.pkl', 'wb') as file:
    pickle.dump({
        'religious_destinations': religious_destinations,
        'camping_destinations': camping_destinations,
        'mountain_destinations': mountain_destinations,
        'sanctuary_destinations': sanctuary_destinations,
        'beach_destinations': beach_destinations,
        'adventure_destinations': adventure_destinations,
        'cultural_destinations': cultural_destinations,
        'nature_wildlife_destinations': nature_wildlife_destinations,
        'wellness_spa_destinations': wellness_spa_destinations,
        'food_culinary_destinations': food_culinary_destinations,
        'destination_feedback_rating' : destination_feedback_rating
    }, file)
